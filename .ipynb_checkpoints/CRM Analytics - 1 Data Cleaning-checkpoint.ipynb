# %% [markdown]
# # **TON CRM Analytics**

# %% [markdown]
# **Impotando bibliotecas necessárias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Importando CSVs para o Jupyter Notebook**

# %%
cases = pd.read_csv('data/cases.csv', date_parser = ['date_ref']) # Cases
creds = pd.read_csv('data/creds.csv', date_parser = ['cred_date']) # Credenciamento

# %% [markdown]
# ### Limpeza do dataset `cases`

# %%
cases.head(5)
# Out:
#    Unnamed: 0           accountid    date_ref  channelid  waitingtime missed  \
# 0           0                 NaN         NaN        NaN          NaN    NaN
# 1           1                 NaN         NaN        NaN          NaN    NaN
# 2           2                 NaN         NaN        NaN          NaN    NaN
# 3           3                 NaN         NaN        NaN          NaN    NaN
# 4           4  0013j00002z0CeEAAU  2020-07-31        2.0         15.0  False
#
#   pesquisa_de_satisfa_o__c                                            assunto  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN  Aplicativo:Dúvidas funcionalidades App:Primeir...
#
#                    Id
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4  0013j00002z0CeEAAU

# %% [markdown]
# **O dataset `cases` não está no melhor formato para a análise.**
#
# Para a limpeza dos dados serão necessários os seguintes passos:
#
# 1. Dropar coluna `Unnamed: 0`;
# 2. Renomear colunas para facilitar o manuseio da base;
# 3. Remover entradas onde todos os valores são nulos;
# 4. Parsear a coluna `date_ref` para o formato datetime;
# 5. Organiar entradas por `data_ref`, em ordem crescente;
# 6. Checar se as colunas `accountid` (PK) e `Id` são redundantes e, caso forem, eliminar `Id`;
# 7. Estudar valores em `channelid` e `wairingtime`, e, caso necessário, transformá-los em `int`;
# 8. Checar se existem entradas duplicada e, em caso positivo, remover redundancias;
# 9. Estudar coluna `assunto` e entender a melhor maneira de guardar informação de maneira estruturada e aplicar;

# %% [markdown]
# #### Renomeando colunas

# %%
# Renomeando colunas:
cases.columns = ['unnamed',
                 'account_id', 
                 'date_ref',
                 'channel_id',
                 'waiting_time',
                 'missed', 
                 'pesq_satisfacao', 
                 'assunto', 
                 'id']

cases.head(3)
# Out:
#    unnamed account_id date_ref  channel_id  waiting_time missed  \
# 0        0        NaN      NaN         NaN           NaN    NaN
# 1        1        NaN      NaN         NaN           NaN    NaN
# 2        2        NaN      NaN         NaN           NaN    NaN
#
#   pesq_satisfacao assunto   id
# 0             NaN     NaN  NaN
# 1             NaN     NaN  NaN
# 2             NaN     NaN  NaN

# %% [markdown]
# #### Dropando `unnamed`

# %%
# Drop "Unnamed: 0"
cases.duplicated('unnamed').sum() # Confirmando se foram criados valores duplicados 
                                     # no índice na criação do dataset
cases = cases.drop('unnamed', axis = 1)

# %% [markdown]
# #### Removendo nulos
#
# Removendo entradas (linhas) com _todos_ os valores nulos:

# %%
cases['account_id'].isna().sum() # PK Cases faltantes
# Out:
# 49500

# %%
# Removendo nulos
ccases = cases.dropna(how = 'all', axis = 0) # ccases = cleaned cases
ccases.shape

# Reportando alterações
print("Qtd entradas dataset original:        ", len(cases), 
      "\nQtd entradas dataset sem NaNs:         ", len(ccases), 
      "\nQtd entradas descartadas após dropna:  ", (len(cases)-len(ccases)))
# Out:
# Qtd entradas dataset original:         126989
# Qtd entradas dataset sem NaNs:          77489
# Qtd entradas descartadas após dropna:   49500

# %%
# Checando valores nulos remanescentes
ccases.isna().sum()
# Out:
# account_id             0
# date_ref               0
# channel_id             0
# waiting_time           0
# missed                 0
# pesq_satisfacao    65904
# assunto                0
# id                     0
# dtype: int64

# %% [markdown]
# #### Investigando `accountid`
#
# **Dúvida: `accountid` atende os requisitos para ser Primary Key do dataset?**
#
# Conforme dicionário dos dados, a coluna `accountid` deveria ser a chave primária (Primary Key, PK) da tabela, para atender a esse requisito, ela deve ser única em cada uma das linhas.
#
# No entando, parece razoavel pensar que no espaço temporal compreendido neste dataset, um mesmo cliente (cada um com um account id único, pode ter realizado varios chamados na central de relacionamento (CR).
#
# Vamos verificar:

# %%
# Checando duplicidade de 'accountid' no dataset
cases.duplicated('account_id').value_counts()
# Out:
# True     95559
# False    31430
# dtype: int64

# %% [markdown]
# **31430 valores _False_** indica que, conforme intuido anteriormente, varias contas chamaram à CR mais de uma vez. Portanto, essa não pode ser a chave primária da tabela.
#
# Como não há uma outra que possa ocupar essa posição, manteremos o index do dataset como chave primária, em que cada linha representa um chamado junto à empresa.

# %% [markdown]
# #### Ordenando dataset a partir de `date_ref`

# %%
# Ordenando dataset
ccases = ccases.sort_values('date_ref')

# %% [markdown]
# #### Checando redundancia
# Verificando se informação das colunas `accountid` (PK) e `Id` é a mesma.

# %%
# Checando se existem valores diferentes em account_id e id
(ccases['account_id'] != ccases['id']).sum()
# Out:
# 0

# %%
# Dropando coluna redundante 'id'
ccases = ccases.drop('id', axis = 1)
# ccases.head(3)

# %% [markdown]
# #### Revisando `channel_id`
# Estudar valores em `channelid` e parsear para `int`, se for o caso.

# %%
ccases['channel_id'].value_counts() # Apenas um valor encontrado; De acordo com o dicionário de dados este canal
                                    # são chamados recebidos via telefone. A coluna pode ser descartada, pois
                                    # a análise agora é especifica para esse canal.
# Out:
# 2.0    77489
# Name: channel_id, dtype: int64

# %%
# Dropando coluna "channel_id"
ccases.drop('channel_id', axis = 1, inplace = True)
# ccases.head(3)

# %% [markdown]
# #### Checando entradas duplicadas

# %%
ccases.duplicated().sum() # Não existem entradas duplicadas.
# Out:
# 0

# %%
ccases = ccases.reset_index(drop = True)
ccases.head(5)
# Out:
#            account_id    date_ref  waiting_time missed pesq_satisfacao  \
# 0  0011L00002ZbpnlQAB  2020-02-23          19.0  False         Enviado
# 1  0011L00002dbBg5QAE  2020-02-25          15.0  False         Enviado
# 2  0011L00002WdgbcQAB  2020-02-26          15.0  False         Enviado
# 3  0011L00002WdJgjQAF  2020-02-26          13.0  False         Enviado
# 4  0011L00002We7cjQAB  2020-02-26          72.0  False         Enviado
#
#                                              assunto
# 0                          Produto:mPOS:Dúvidas mpos
# 1                               Aplicativo:Problema:
# 2  Aplicativo:Dúvidas funcionalidades App:Redefin...
# 3              Produto:mPOS:Problema POS - revertido
# 4                                       Aplicativo::

# %%
# ccases.tail(5)

# %% [markdown]
# #### Parseando `date_ref`
# Mudando dados da colunas para formato datetime

# %%
# Formatando data type da coluna "date_ref"
ccases['date_ref'] = pd.to_datetime(ccases['date_ref'])
# ccases.info()

# %% [markdown]
# #### Feature engineering dados temporais
# Transformando coluna `waiting_time` (medido em segundos) para dtype `int` e `timedelta` (para operações com data e hora)

# %%
ccases['waiting_time'] = ccases['waiting_time'].astype(int)

# %%
ccases['waiting_time'] = ccases['waiting_time'].astype(int)
ccases['waiting_timedelta'] = pd.to_timedelta(ccases['waiting_time'], unit = 'S')

# %%
def explode_date(df, date_column, language_ptbr = True):
    '''Generates year, month, day and weekday from a single date column.
        
    :::::::
    
    df:            DataFrame containing the date column to be exploded.
    date_column:   Date column (Series) to be used as base for the transformation.
    language_ptbr: If True, parse weekday names to Brazilian Portuguese. 
                      False, weekdays will be parsed to English.
    
    :::::::

    '''
    df[date_column] = pd.to_datetime(df[date_column])
    df['year'] = df[date_column].dt.year 
    df['month'] = df[date_column].dt.month
    df['day'] = df[date_column].dt.day
    df['weekday'] = df[date_column].dt.weekday
    
    if language_ptbr:
        df['weekday_str'] = df['weekday'].map({
                                    0: 'Seg',
                                    1: 'Ter',
                                    2: 'Qua',
                                    3: 'Qui',
                                    4: 'Sex',
                                    5: 'Sab',
                                    6: 'Dom'
                            })
    else:
        df['weekday_str'] = df[date_column].dt.day_name().str[0:3]

    return df

# %%
ccases = explode_date(ccases, 'date_ref', language_ptbr = True)
ccases.head(3)
# Out:
#            account_id   date_ref  waiting_time missed pesq_satisfacao  \
# 0  0011L00002ZbpnlQAB 2020-02-23            19  False         Enviado
# 1  0011L00002dbBg5QAE 2020-02-25            15  False         Enviado
# 2  0011L00002WdgbcQAB 2020-02-26            15  False         Enviado
#
#                                              assunto waiting_timedelta  year  \
# 0                          Produto:mPOS:Dúvidas mpos          00:00:19  2020
# 1                               Aplicativo:Problema:          00:00:15  2020
# 2  Aplicativo:Dúvidas funcionalidades App:Redefin...          00:00:15  2020
#
#    month  day  weekday weekday_str
# 0      2   23        6         Dom
# 1      2   25        1         Ter
# 2      2   26        2         Qua

# %% [markdown]
# #### Estrutundo dados em `assunto`

# %%
# Separando os tópicos encadeados e guardando em uma lista
ccases['assunto'] = ccases['assunto'].str.split(':')

# %%
# Criando colunas especificas para cada um dos tópicos
ccases[['node_1','node_2', 'node_3']] = pd.DataFrame(ccases['assunto'].tolist(), index = ccases.index)

# Preenchendo colunas nulas com NaNs
ccases[['node_1', 'node_2', 'node_3']] = ccases[['node_1', 'node_2', 'node_3']].replace('', np.nan)
ccases.head(3)
# Out:
#            account_id   date_ref  waiting_time missed pesq_satisfacao  \
# 0  0011L00002ZbpnlQAB 2020-02-23            19  False         Enviado
# 1  0011L00002dbBg5QAE 2020-02-25            15  False         Enviado
# 2  0011L00002WdgbcQAB 2020-02-26            15  False         Enviado
#
#                                              assunto waiting_timedelta  year  \
# 0                      [Produto, mPOS, Dúvidas mpos]          00:00:19  2020
# 1                           [Aplicativo, Problema, ]          00:00:15  2020
# 2  [Aplicativo, Dúvidas funcionalidades App, Rede...          00:00:15  2020
#
#    month  day  weekday weekday_str      node_1                       node_2  \
# 0      2   23        6         Dom     Produto                         mPOS
# 1      2   25        1         Ter  Aplicativo                     Problema
# 2      2   26        2         Qua  Aplicativo  Dúvidas funcionalidades App
#
#                  node_3
# 0          Dúvidas mpos
# 1                   NaN
# 2  Redefinição de senha

# %% [markdown]
# ### Limpeza do dataset `creds`.

# %%
creds.head(3)
# Out:
#    Unnamed: 0   cred_date shipping_address_city shipping_address_state  \
# 0           0  2020-04-18      Feira de Santana                     BA
# 1           1  2020-10-16                Bacuri                     MA
# 2           2  2020-09-01        Bernardo Sayão                     TO
#
#   max_machine accountid
# 0          T1       NaN
# 1          T1       NaN
# 2          T1       NaN

# %%
creds.columns = ['unnamed', 'cred_date', 'ship_city', 'ship_state', 'max_machine', 'account_id']
creds.head(3)
# Out:
#    unnamed   cred_date         ship_city ship_state max_machine account_id
# 0        0  2020-04-18  Feira de Santana         BA          T1        NaN
# 1        1  2020-10-16            Bacuri         MA          T1        NaN
# 2        2  2020-09-01    Bernardo Sayão         TO          T1        NaN

# %%
creds = creds.drop('unnamed', axis = 1)
creds.head(3)
# Out:
#     cred_date         ship_city ship_state max_machine account_id
# 0  2020-04-18  Feira de Santana         BA          T1        NaN
# 1  2020-10-16            Bacuri         MA          T1        NaN
# 2  2020-09-01    Bernardo Sayão         TO          T1        NaN

# %%
explode_date(creds, 'cred_date', language_ptbr = True)
# Out:
#         cred_date                  ship_city ship_state max_machine  \
# 0      2020-04-18           Feira de Santana         BA          T1
# 1      2020-10-16                     Bacuri         MA          T1
# 2      2020-09-01             Bernardo Sayão         TO          T1
# 3      2020-08-29             Rio de Janeiro         RJ          T3
# 4      2020-07-28                São Gonçalo         RJ          T3
# 5      2020-07-28                São Gonçalo         RJ          T3
# 6      2020-07-28                São Gonçalo         RJ          T3
# 7      2020-08-28                   Itaboraí         RJ          T1
# 8      2020-08-28                   Itaboraí         RJ          T1
# 9      2020-08-28                   Itaboraí         RJ          T1
# 10     2020-08-28                   Itaboraí         RJ          T1
# 11     2020-10-28                    Biguaçu         SC          T1
# 12     2020-10-27                   Contagem         MG          T1
# 13     2020-09-01                    Videira         SC          T1
# 14     2020-09-30                     Canela         RS          T1
# 15     2020-10-02                  Joinville         SC          T1
# 16     2020-10-02                  Joinville         SC          T1
# 17     2020-09-25                     Laguna         SC          T1
# 18     2019-08-31             Rio de Janeiro         RJ          T1
# 19     2020-05-17             Belo Horizonte         MG          T3
# 20     2020-08-25                   São José         SC          T3
# 21     2020-10-09  Porto Alegre do Tocantins         TO          T3
# 22     2020-09-23                   Itaboraí         RJ          T1
# 23     2020-07-24         São João de Meriti         RJ          T2
# 24     2020-07-24         São João de Meriti         RJ          T2
# 25     2020-07-29                Nortelândia         MT          T1
# 26     2020-08-17        Cocalzinho de Goiás         GO          T3
# 27     2020-08-17        Cocalzinho de Goiás         GO          T3
# 28     2020-07-25        Valparaíso de Goiás         GO          T3
# 29     2020-07-10             Rio de Janeiro         RJ          T2
# ...           ...                        ...        ...         ...
# 126959 2020-04-22                   Anápolis         GO          T3
# 126960 2020-07-16                São Gonçalo         RJ          T3
# 126961 2020-08-21                   Calçoene         AP          T2
# 126962 2020-08-21                   Calçoene         AP          T2
# 126963 2020-09-26           Cidade Ocidental         GO          T3
# 126964 2020-09-26           Cidade Ocidental         GO          T3
# 126965 2020-09-26           Cidade Ocidental         GO          T3
# 126966 2020-09-26           Cidade Ocidental         GO          T3
# 126967 2020-09-05                    Aracaju         SE          T1
# 126968 2020-08-06                  Fortaleza         CE          T3
# 126969 2020-08-06                  Fortaleza         CE          T3
# 126970 2020-08-06                  Fortaleza         CE          T3
# 126971 2020-06-18                    Aracaju         SE          T3
# 126972 2020-06-18                    Aracaju         SE          T3
# 126973 2020-10-20           Feira de Santana         BA          T2
# 126974 2020-07-31                    Niterói         RJ          T2
# 126975 2020-09-16                     Itajaí         SC          T3
# 126976 2020-09-16                     Itajaí         SC          T3
# 126977 2020-09-16                     Itajaí         SC          T3
# 126978 2020-09-16                     Itajaí         SC          T3
# 126979 2020-09-16                     Itajaí         SC          T3
# 126980 2020-09-16                     Itajaí         SC          T3
# 126981 2020-09-28                    Niterói         RJ          T3
# 126982 2020-06-20                 Petrópolis         RJ          T2
# 126983 2020-06-20                 Petrópolis         RJ          T2
# 126984 2020-06-20                 Petrópolis         RJ          T2
# 126985 2020-06-20                 Petrópolis         RJ          T2
# 126986 2020-06-20                 Petrópolis         RJ          T2
# 126987 2020-06-20                 Petrópolis         RJ          T2
# 126988 2020-06-20                 Petrópolis         RJ          T2
#
#                 account_id  year  month  day  weekday weekday_str
# 0                      NaN  2020      4   18        5         Sab
# 1                      NaN  2020     10   16        4         Sex
# 2                      NaN  2020      9    1        1         Ter
# 3                      NaN  2020      8   29        5         Sab
# 4       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 5       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 6       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 7       0013j00002zQgldAAC  2020      8   28        4         Sex
# 8       0013j00002zQgldAAC  2020      8   28        4         Sex
# 9       0013j00002zQgldAAC  2020      8   28        4         Sex
# 10      0013j00002zQgldAAC  2020      8   28        4         Sex
# 11                     NaN  2020     10   28        2         Qua
# 12                     NaN  2020     10   27        1         Ter
# 13                     NaN  2020      9    1        1         Ter
# 14                     NaN  2020      9   30        2         Qua
# 15      0013j0000304oN9AAI  2020     10    2        4         Sex
# 16      0013j0000304oN9AAI  2020     10    2        4         Sex
# 17                     NaN  2020      9   25        4         Sex
# 18                     NaN  2019      8   31        5         Sab
# 19                     NaN  2020      5   17        6         Dom
# 20                     NaN  2020      8   25        1         Ter
# 21                     NaN  2020     10    9        4         Sex
# 22                     NaN  2020      9   23        2         Qua
# 23      0013j00002yzpxZAAQ  2020      7   24        4         Sex
# 24      0013j00002yzpxZAAQ  2020      7   24        4         Sex
# 25      0013j00002z0RA5AAM  2020      7   29        2         Qua
# 26      0013j00002zOcuAAAS  2020      8   17        0         Seg
# 27      0013j00002zOcuAAAS  2020      8   17        0         Seg
# 28                     NaN  2020      7   25        5         Sab
# 29      0013j00002yp2xzAAA  2020      7   10        4         Sex
# ...                    ...   ...    ...  ...      ...         ...
# 126959  0013j00002teCDNAA2  2020      4   22        2         Qua
# 126960                 NaN  2020      7   16        3         Qui
# 126961  0013j00002zPBvnAAG  2020      8   21        4         Sex
# 126962  0013j00002zPBvnAAG  2020      8   21        4         Sex
# 126963  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126964  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126965  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126966  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126967                 NaN  2020      9    5        5         Sab
# 126968  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126969  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126970  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126971  0013j00002ye8jtAAA  2020      6   18        3         Qui
# 126972  0013j00002ye8jtAAA  2020      6   18        3         Qui
# 126973                 NaN  2020     10   20        1         Ter
# 126974  0013j00002z1AyaAAE  2020      7   31        4         Sex
# 126975  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126976  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126977  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126978  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126979  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126980  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126981                 NaN  2020      9   28        0         Seg
# 126982  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126983  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126984  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126985  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126986  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126987  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126988  0013j00002yi49FAAQ  2020      6   20        5         Sab
#
# [126989 rows x 10 columns]

# %%
creds
# Out:
#         cred_date                  ship_city ship_state max_machine  \
# 0      2020-04-18           Feira de Santana         BA          T1
# 1      2020-10-16                     Bacuri         MA          T1
# 2      2020-09-01             Bernardo Sayão         TO          T1
# 3      2020-08-29             Rio de Janeiro         RJ          T3
# 4      2020-07-28                São Gonçalo         RJ          T3
# 5      2020-07-28                São Gonçalo         RJ          T3
# 6      2020-07-28                São Gonçalo         RJ          T3
# 7      2020-08-28                   Itaboraí         RJ          T1
# 8      2020-08-28                   Itaboraí         RJ          T1
# 9      2020-08-28                   Itaboraí         RJ          T1
# 10     2020-08-28                   Itaboraí         RJ          T1
# 11     2020-10-28                    Biguaçu         SC          T1
# 12     2020-10-27                   Contagem         MG          T1
# 13     2020-09-01                    Videira         SC          T1
# 14     2020-09-30                     Canela         RS          T1
# 15     2020-10-02                  Joinville         SC          T1
# 16     2020-10-02                  Joinville         SC          T1
# 17     2020-09-25                     Laguna         SC          T1
# 18     2019-08-31             Rio de Janeiro         RJ          T1
# 19     2020-05-17             Belo Horizonte         MG          T3
# 20     2020-08-25                   São José         SC          T3
# 21     2020-10-09  Porto Alegre do Tocantins         TO          T3
# 22     2020-09-23                   Itaboraí         RJ          T1
# 23     2020-07-24         São João de Meriti         RJ          T2
# 24     2020-07-24         São João de Meriti         RJ          T2
# 25     2020-07-29                Nortelândia         MT          T1
# 26     2020-08-17        Cocalzinho de Goiás         GO          T3
# 27     2020-08-17        Cocalzinho de Goiás         GO          T3
# 28     2020-07-25        Valparaíso de Goiás         GO          T3
# 29     2020-07-10             Rio de Janeiro         RJ          T2
# ...           ...                        ...        ...         ...
# 126959 2020-04-22                   Anápolis         GO          T3
# 126960 2020-07-16                São Gonçalo         RJ          T3
# 126961 2020-08-21                   Calçoene         AP          T2
# 126962 2020-08-21                   Calçoene         AP          T2
# 126963 2020-09-26           Cidade Ocidental         GO          T3
# 126964 2020-09-26           Cidade Ocidental         GO          T3
# 126965 2020-09-26           Cidade Ocidental         GO          T3
# 126966 2020-09-26           Cidade Ocidental         GO          T3
# 126967 2020-09-05                    Aracaju         SE          T1
# 126968 2020-08-06                  Fortaleza         CE          T3
# 126969 2020-08-06                  Fortaleza         CE          T3
# 126970 2020-08-06                  Fortaleza         CE          T3
# 126971 2020-06-18                    Aracaju         SE          T3
# 126972 2020-06-18                    Aracaju         SE          T3
# 126973 2020-10-20           Feira de Santana         BA          T2
# 126974 2020-07-31                    Niterói         RJ          T2
# 126975 2020-09-16                     Itajaí         SC          T3
# 126976 2020-09-16                     Itajaí         SC          T3
# 126977 2020-09-16                     Itajaí         SC          T3
# 126978 2020-09-16                     Itajaí         SC          T3
# 126979 2020-09-16                     Itajaí         SC          T3
# 126980 2020-09-16                     Itajaí         SC          T3
# 126981 2020-09-28                    Niterói         RJ          T3
# 126982 2020-06-20                 Petrópolis         RJ          T2
# 126983 2020-06-20                 Petrópolis         RJ          T2
# 126984 2020-06-20                 Petrópolis         RJ          T2
# 126985 2020-06-20                 Petrópolis         RJ          T2
# 126986 2020-06-20                 Petrópolis         RJ          T2
# 126987 2020-06-20                 Petrópolis         RJ          T2
# 126988 2020-06-20                 Petrópolis         RJ          T2
#
#                 account_id  year  month  day  weekday weekday_str
# 0                      NaN  2020      4   18        5         Sab
# 1                      NaN  2020     10   16        4         Sex
# 2                      NaN  2020      9    1        1         Ter
# 3                      NaN  2020      8   29        5         Sab
# 4       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 5       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 6       0013j00002z0CeEAAU  2020      7   28        1         Ter
# 7       0013j00002zQgldAAC  2020      8   28        4         Sex
# 8       0013j00002zQgldAAC  2020      8   28        4         Sex
# 9       0013j00002zQgldAAC  2020      8   28        4         Sex
# 10      0013j00002zQgldAAC  2020      8   28        4         Sex
# 11                     NaN  2020     10   28        2         Qua
# 12                     NaN  2020     10   27        1         Ter
# 13                     NaN  2020      9    1        1         Ter
# 14                     NaN  2020      9   30        2         Qua
# 15      0013j0000304oN9AAI  2020     10    2        4         Sex
# 16      0013j0000304oN9AAI  2020     10    2        4         Sex
# 17                     NaN  2020      9   25        4         Sex
# 18                     NaN  2019      8   31        5         Sab
# 19                     NaN  2020      5   17        6         Dom
# 20                     NaN  2020      8   25        1         Ter
# 21                     NaN  2020     10    9        4         Sex
# 22                     NaN  2020      9   23        2         Qua
# 23      0013j00002yzpxZAAQ  2020      7   24        4         Sex
# 24      0013j00002yzpxZAAQ  2020      7   24        4         Sex
# 25      0013j00002z0RA5AAM  2020      7   29        2         Qua
# 26      0013j00002zOcuAAAS  2020      8   17        0         Seg
# 27      0013j00002zOcuAAAS  2020      8   17        0         Seg
# 28                     NaN  2020      7   25        5         Sab
# 29      0013j00002yp2xzAAA  2020      7   10        4         Sex
# ...                    ...   ...    ...  ...      ...         ...
# 126959  0013j00002teCDNAA2  2020      4   22        2         Qua
# 126960                 NaN  2020      7   16        3         Qui
# 126961  0013j00002zPBvnAAG  2020      8   21        4         Sex
# 126962  0013j00002zPBvnAAG  2020      8   21        4         Sex
# 126963  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126964  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126965  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126966  0013j0000303OJPAA2  2020      9   26        5         Sab
# 126967                 NaN  2020      9    5        5         Sab
# 126968  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126969  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126970  0013j00002z1gZ4AAI  2020      8    6        3         Qui
# 126971  0013j00002ye8jtAAA  2020      6   18        3         Qui
# 126972  0013j00002ye8jtAAA  2020      6   18        3         Qui
# 126973                 NaN  2020     10   20        1         Ter
# 126974  0013j00002z1AyaAAE  2020      7   31        4         Sex
# 126975  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126976  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126977  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126978  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126979  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126980  0013j00002zfshHAAQ  2020      9   16        2         Qua
# 126981                 NaN  2020      9   28        0         Seg
# 126982  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126983  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126984  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126985  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126986  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126987  0013j00002yi49FAAQ  2020      6   20        5         Sab
# 126988  0013j00002yi49FAAQ  2020      6   20        5         Sab
#
# [126989 rows x 10 columns]

# %% [markdown]
# ---

# %%
creds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126989 entries, 0 to 126988
# Data columns (total 10 columns):
# cred_date      126989 non-null datetime64[ns]
# ship_city      126989 non-null object
# ship_state     126989 non-null object
# max_machine    126989 non-null object
# account_id     77489 non-null object
# year           126989 non-null int64
# month          126989 non-null int64
# day            126989 non-null int64
# weekday        126989 non-null int64
# weekday_str    126989 non-null object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 9.7+ MB

# %% [markdown]
# # TO INCLUDE IN THE ANALYSIS

# %%
# Contando quantidade de tópicos por node
print('Qtd. tópicos no node_1:  ', ccases['node_1'].nunique(dropna = False))
print('Qtd. tópicos no node_2:  ', ccases['node_2'].nunique(dropna = False))
print('Qtd. tópicos no node_3: ', ccases['node_3'].nunique(dropna = False), '\n')

print('Qtd. valores faltantes no node_1:   ', ccases['node_1'].isna().sum(), '<-- What are those?')
print('Qtd. valores faltantes no node_2:  ', ccases['node_2'].isna().sum())
print('Qtd. valores faltantes no node_3: ', ccases['node_3'].isna().sum())

# Transformando tópicos em sets para avaliar se são subsets uns dos outros
topics_node_1 = set(ccases['node_1'].value_counts(dropna = False).index.tolist())
topics_node_2 = set(ccases['node_2'].value_counts(dropna = False).index.tolist())
topics_node_3 = set(ccases['node_3'].value_counts(dropna = False).index.tolist())
# Out:
# Qtd. tópicos no node_1:   16
# Qtd. tópicos no node_2:   48
# Qtd. tópicos no node_3:  108
#
# Qtd. valores faltantes no node_1:    106 <-- What are those?
# Qtd. valores faltantes no node_2:   1719
# Qtd. valores faltantes no node_3:  11925

# %%
# Checando se sets são subsets uns dos outros
topics_node_2.issubset(topics_node_1), \
topics_node_3.issubset(topics_node_2), \
topics_node_3.issubset(topics_node_1)
# Out:
# (False, False, False)

# %%
ccases[ccases['node_1'].isna()].head(10)
# Out:
#                account_id   date_ref  waiting_time missed pesq_satisfacao  \
# 7086   0011L00002ZdlooQAB 2020-06-03             7  False             NaN
# 7164   0013j00002u26qOAAQ 2020-06-03            15  False             NaN
# 8229   0013j00002u3MSdAAM 2020-06-09            14  False             NaN
# 8276   0013j00002u39oXAAQ 2020-06-09             8  False             NaN
# 8495   0013j00002txEiSAAU 2020-06-10             5  False             NaN
# 9376   0013j00002tvWXUAA2 2020-06-15            16  False             NaN
# 9851   0013j00002y78b5AAA 2020-06-16            13  False             NaN
# 10133  0013j00002y9LZpAAM 2020-06-17             8  False             NaN
# 10728  0013j00002tgZb2AAE 2020-06-19            12  False             NaN
# 10950  0013j00002u44OLAAY 2020-06-20            12  False             NaN
#
#       assunto waiting_timedelta  year  month  day  weekday weekday_str node_1  \
# 7086   [, , ]          00:00:07  2020      6    3        2         Qua    NaN
# 7164   [, , ]          00:00:15  2020      6    3        2         Qua    NaN
# 8229   [, , ]          00:00:14  2020      6    9        1         Ter    NaN
# 8276   [, , ]          00:00:08  2020      6    9        1         Ter    NaN
# 8495   [, , ]          00:00:05  2020      6   10        2         Qua    NaN
# 9376   [, , ]          00:00:16  2020      6   15        0         Seg    NaN
# 9851   [, , ]          00:00:13  2020      6   16        1         Ter    NaN
# 10133  [, , ]          00:00:08  2020      6   17        2         Qua    NaN
# 10728  [, , ]          00:00:12  2020      6   19        4         Sex    NaN
# 10950  [, , ]          00:00:12  2020      6   20        5         Sab    NaN
#
#       node_2 node_3
# 7086     NaN    NaN
# 7164     NaN    NaN
# 8229     NaN    NaN
# 8276     NaN    NaN
# 8495     NaN    NaN
# 9376     NaN    NaN
# 9851     NaN    NaN
# 10133    NaN    NaN
# 10728    NaN    NaN
# 10950    NaN    NaN

# %%
# assunto = ccases.copy()
# assunto['assunto'] = assunto['assunto'].str.split(':')

# chain_count = []
# for i in range(len(assunto)):
#     count = len(assunto['assunto'][i])
#     chain_count.append(count)

# %%
# assunto['chain_count'] = chain_count

# %%
# assunto['chain_count'].value_counts()

# %%
# empty_last_chain = 0
# idx = []
# for i, index in enumerate(range(len(assunto))):
#     if assunto['assunto'][i][-1] == '':
#         empty_last_chain += 1
#         idx.append(i)

# %%
# assunto.iloc[idx, :]

# %%
# empty_last_chain

# %%
# assunto['chain_count'].value_counts()

# %%
# cases['missed'].value_counts()

# %%
# sns.boxplot(ccases.loc[ccases['missed'] == False, 'waiting_time']);

# %%
# ccases[ccases['missed'] == True]

# %%
# creds.head()

# %%
# creds['cred_date'] = pd.to_datetime(creds['cred_date'])
# creds.info()
